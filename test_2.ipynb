# %% [markdown]
# <a href="https://colab.research.google.com/github/serhhpi/bbb/blob/main/test_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve, roc_auc_score, auc

# %%
# Загрузка данных из CSV
import io
from google.colab import files

uploaded = files.upload()

df = pd.read_csv(io.BytesIO(uploaded['action_test2.csv']))
# Out:
#      <input type="file" id="files-1c79cd05-7d89-4413-ab59-bc89778cb91f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1c79cd05-7d89-4413-ab59-bc89778cb91f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df
# Out:
#        Unnamed: 0   person_id     action_id        date action_type   char_1  \
# 0               0  ppl_100004   act1_249281  2022-07-20      type 1   type 5
# 1               1  ppl_100004   act2_230855  2022-07-20      type 5      NaN
# 2               2   ppl_10001   act1_240724  2022-10-14      type 1  type 12
# 3               3   ppl_10001    act1_83552  2022-11-27      type 1  type 20
# 4               4   ppl_10001  act2_1043301  2022-10-15      type 5      NaN
# ...           ...         ...           ...         ...         ...      ...
# 35245       35245  ppl_123451  act2_2368636  2022-08-20      type 2      NaN
# 35246       35246  ppl_123451  act2_2388652  2023-02-13      type 2      NaN
# 35247       35247  ppl_123451  act2_2411075  2022-10-20      type 2      NaN
# 35248       35248  ppl_123451  act2_2476113  2022-08-13      type 2      NaN
# 35249       35249  ppl_123451  act2_2558528  2023-02-10      type 2      NaN
#
# ...

# %%
X = df.drop('action_id', axis=1)  # Признаки
y = df['action_id']              # Целевая переменная
df.shape
# Out:
# (35250, 15)

# %%
# Разделение на тренировочную и тестовую выборки
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Обучение модели (Random Forest)
model = CatBoostClassifier(verbose=False)
model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-e4d6e9a18e17> in <cell line: 0>()
#       1 # Обучение модели (Random Forest)
# ----> 2 model = CatBoostClassifier(verbose=False)
#       3 model.fit(X_train, y_train)
#
# NameError: name 'CatBoostClassifier' is not defined
